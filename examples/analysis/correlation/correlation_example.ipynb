# %% [markdown]
# # Two-Point Correlation Function Example
#
# This notebook demonstrates how to compute the real-space two-point correlation function (2PCF) using `galform_analysis`.

# %%
import matplotlib.pyplot as plt
import numpy as np
from galform_analysis.src.analysis.correlation.correlation import avg_correlation_given_redshift_and_subvolumes
from galform_analysis.src.config import get_base_dir

# Set parameters
iz_num = 155
ivols = [0, 1, 2, 3]  # Example subvolumes
base_dir = get_base_dir()

# Compute averaged 2PCF
corr_result = avg_correlation_given_redshift_and_subvolumes(iz_num, ivols, base_dir=str(base_dir))

if corr_result is not None:
    plt.figure(figsize=(8, 6))
    plt.plot(corr_result['r'], corr_result['xi'], 'o-')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('r [Mpc/h]')
    plt.ylabel('xi(r)')
    plt.title(f'Two-Point Correlation Function ({corr_result.attrs["iz"]}, z={corr_result.attrs.get("z", "N/A")})')
    plt.grid(True)
    plt.show()
else:
    print("No data found.")
