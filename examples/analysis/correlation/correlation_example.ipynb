# %% [markdown]
# # 2PCF Example

# %%
import sys, os
if '/cosma/apps/durham/dc-hick2/galform_analysis' not in sys.path: sys.path.append('/cosma/apps/durham/dc-hick2/galform_analysis')
import matplotlib.pyplot as plt
from src.analysis.correlation.correlation import avg_correlation_given_redshift_and_subvolumes
from src.config import get_base_dir

res = avg_correlation_given_redshift_and_subvolumes(155, [0, 1], base_dir=str(get_base_dir()))
plt.plot(res['r'], res['xi'], 'o-')
plt.xscale('log')
plt.yscale('log')
plt.show()
