# %% [markdown]
# # Halo Mass Function Example

# %%
import sys, os
if '/cosma/apps/durham/dc-hick2/galform_analysis' not in sys.path: sys.path.append('/cosma/apps/durham/dc-hick2/galform_analysis')
import matplotlib.pyplot as plt
import numpy as np
from src.analysis.mass_functions.hmf import avg_hmf_given_redshift_and_subvolumes
from src.analysis.mass_functions.theoretical_hmf import compute_theoretical_hmfs
from src.config import get_base_dir

iz_num, ivols = 155, [0, 1, 2, 3]
base_dir = get_base_dir()

hmf_result = avg_hmf_given_redshift_and_subvolumes(iz_num, ivols, base_dir=str(base_dir))
z = hmf_result['z']
theory = compute_theoretical_hmfs(z=z, bins=hmf_result['centers'])

plt.figure(figsize=(8, 6))
plt.errorbar(hmf_result['centers'], hmf_result['phi'], yerr=hmf_result['phi_std'], fmt='o', label='Simulation')
plt.plot(theory['centers'], theory['phi'], '--', label='Jenkins')
plt.yscale('log')
plt.xlabel('log10(M_halo)')
plt.ylabel('phi')
plt.legend()
plt.show()
