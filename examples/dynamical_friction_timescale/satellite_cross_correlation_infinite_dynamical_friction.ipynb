# %% [markdown]
# # Satellite–Central Cross-Correlation
# Compute the cross-correlation $\xi_{\mathrm{sat,cen}}(r)$ between satellite and central galaxies from GALFORM galaxies.hdf5 outputs.

# %% [markdown]
# ## Import Libraries

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from galform_analysis.config import get_base_dir, DEFAULT_RBINS, get_snapshot_redshift
from galform_analysis.analysis.correlation import satellite_central_cross_correlation

project_root = Path.cwd().resolve().parents[1]
if str(project_root / 'src') not in sys.path:
    sys.path.insert(0, str(project_root / 'src'))

plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['font.size'] = 11

base_dir = Path('/cosma5/data/durham/dc-hick2/Tau0_Investigation/Galform_Out_1e6tau0/L800/lc16.newmg')

# %% [markdown]
# ## Cross-correlation for a single redshift and subvolume

# %%
example_snapshot = 'iz207'
example_ivol = 1
satellite_stellar_mass_min = 1e9  # Msun/h
central_stellar_mass_min = 1e9
host_halo_mass_min = 1e9

cross = satellite_central_cross_correlation(
    base_dir / example_snapshot,
    example_ivol,
    rbins=DEFAULT_RBINS,
    nthreads=4,
    satellite_stellar_mass_min=satellite_stellar_mass_min,
    central_stellar_mass_min=central_stellar_mass_min,
    host_halo_mass_min=host_halo_mass_min,
)
z_val = cross.attrs.get('z')
if z_val is None:
    z_val = get_snapshot_redshift(example_snapshot)
z_label = f"{z_val:.3f}" if z_val is not None else "n/a"

print(
    f"Loaded cross-correlation for {cross.attrs['iz']} (z={z_label}), ",
    f"ivol={cross.attrs['ivol']}; N_sat={cross.attrs['n_sat']}, N_cen={cross.attrs['n_cen']}.",
)
# Out:
# Warning: satellite-central cross-correlation failed for /cosma5/data/durham/dc-hick2/Tau0_Investigation/Galform_Out_1e6tau0/L800/lc16.newmg/iz207/ivol1: FileNotFoundError: Missing or unreadable galaxies.hdf5 at /cosma5/data/durham/dc-hick2/Tau0_Investigation/Galform_Out_1e6tau0/L800/lc16.newmg/iz207/ivol1
# Traceback (most recent call last):
#   File "/cosma/home/durham/dc-hick2/galform_analysis/src/galform_analysis/analysis/correlation/satellite_cross_correlation.py", line 197, in satellite_central_cross_correlation
#     pos_sat, z_sat = _load_galaxy_positions(
#   File "/cosma/home/durham/dc-hick2/galform_analysis/src/galform_analysis/analysis/correlation/satellite_cross_correlation.py", line 49, in _load_galaxy_positions
#     raise FileNotFoundError(f"Missing or unreadable galaxies.hdf5 at {iz_path}/ivol{ivol}")
# FileNotFoundError: Missing or unreadable galaxies.hdf5 at /cosma5/data/durham/dc-hick2/Tau0_Investigation/Galform_Out_1e6tau0/L800/lc16.newmg/iz207/ivol1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#       5 host_halo_mass_min = 1e9
#       7 cross = satellite_central_cross_correlation(
#       8     base_dir / example_snapshot,
#       9     example_ivol,
#    (...)
#      14     host_halo_mass_min=host_halo_mass_min,
#      15 )
# ---> 16 z_val = cross.attrs.get('z')
#      17 if z_val is None:
#      18     z_val = get_snapshot_redshift(example_snapshot)
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
r = cross['r'].values
xi = cross['xi'].values
valid = np.isfinite(xi) & (xi > -1)

fig, ax = plt.subplots(figsize=(8, 5))
ax.loglog(r[valid], xi[valid], 'o-')
ax.set_xlabel('Separation r [Mpc/h]')
ax.set_ylabel(r'$\xi_{\mathrm{sat,cen}}(r)$')
ax.set_title('Satellite–Central Cross-Correlation')
ax.grid(True, alpha=0.3, which='both')
plt.show()

# %% [markdown]
# ## Compare two redshifts

# %%
fig, ax = plt.subplots(figsize=(8, 5))

for snapshot in ['iz271', 'iz207']:
    res = satellite_central_cross_correlation(
        base_dir / snapshot,
        example_ivol,
        rbins=DEFAULT_RBINS,
        nthreads=4,
        satellite_stellar_mass_min=satellite_stellar_mass_min,
        central_stellar_mass_min=central_stellar_mass_min,
        host_halo_mass_min=host_halo_mass_min,
    )
    if res is None:
        print(f"Skipped {snapshot}: no data")
        continue
    r = res['r'].values
    xi = res['xi'].values
    valid = np.isfinite(xi) & (xi > -1)
    if not np.any(valid):
        print(f"Skipped {snapshot}: no finite xi")
        continue
    z_val = res.attrs.get('z')
    if z_val is None:
        z_val = get_snapshot_redshift(snapshot)
    z_label = f"{z_val:.2f}" if z_val is not None else "n/a"
    ax.loglog(r[valid], xi[valid], 'o-', label=f"{snapshot} (z={z_label})")

ax.set_xlabel('Separation r [Mpc/h]')
ax.set_ylabel(r'$\xi_{\mathrm{sat,cen}}(r)$')
ax.set_title('Satellite–Central Cross-Correlation Across Redshift')
ax.legend()
ax.set_ylim(1e-3, 1e5)
ax.grid(True, alpha=0.3, which='both')
plt.show()

# %% [markdown]
# ## Cross-correlation across multiple redshifts

# %%
snapshots = ['iz207', 'iz271']
fig, ax = plt.subplots(figsize=(8, 5))

for snapshot in snapshots:
    res = satellite_central_cross_correlation(
        base_dir / snapshot,
        example_ivol,
        rbins=DEFAULT_RBINS,
        nthreads=4,
        satellite_stellar_mass_min=satellite_stellar_mass_min,
        central_stellar_mass_min=central_stellar_mass_min,
        host_halo_mass_min=host_halo_mass_min,
    )
    if res is None:
        print(f"Skipped {snapshot}: no data")
        continue
    r = res['r'].values
    xi = res['xi'].values
    valid = np.isfinite(xi) & (xi > -1)
    if not np.any(valid):
        print(f"Skipped {snapshot}: no finite xi")
        continue
    z_val = res.attrs.get('z')
    if z_val is None:
        z_val = get_snapshot_redshift(snapshot)
    z_label = f"{z_val:.2f}" if z_val is not None else "n/a"
    ax.loglog(r[valid], xi[valid], 'o-', label=f"{snapshot} (z={z_label})")

ax.set_xlabel('Separation r [Mpc/h]')
ax.set_ylabel(r'$\xi_{\mathrm{sat,cen}}(r)$')
ax.set_title('Satellite–Central Cross-Correlation (multiple redshifts)')
ax.legend(ncol=2, fontsize=9)
ax.grid(True, alpha=0.3, which='both')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 snapshots = ['iz207', 'iz271']
# ----> 2 fig, ax = plt.subplots(figsize=(8, 5))
#       4 for snapshot in snapshots:
#       5     res = satellite_central_cross_correlation(
#       6         base_dir / snapshot,
#       7         example_ivol,
#    (...)
#      12         host_halo_mass_min=host_halo_mass_min,
#      13     )
#
# NameError: name 'plt' is not defined

# %%
snapshots = ['iz207', 'iz271']  # ['iz82', 'iz100', 'iz120', 'iz207', 'iz271']
ivols = list(range(0, 15))  # Independent samples to combine; adjust to available ivols.
r_ref = 0.5 * (DEFAULT_RBINS[:-1] + DEFAULT_RBINS[1:])

fig, ax = plt.subplots(figsize=(8, 5))

for snapshot in snapshots:
    xi_stack = []
    n_used = 0
    for ivol in ivols:
        res = satellite_central_cross_correlation(
            base_dir / snapshot,
            ivol,
            rbins=DEFAULT_RBINS,
            nthreads=4,
            satellite_stellar_mass_min=satellite_stellar_mass_min,
            central_stellar_mass_min=central_stellar_mass_min,
            host_halo_mass_min=host_halo_mass_min,
        )
        if res is None:
            continue
        xi_vals = res['xi'].values
        if np.all(np.isfinite(xi_vals) | np.isnan(xi_vals)):
            xi_stack.append(xi_vals)
            n_used += 1
    if n_used == 0:
        print(f"Skipped {snapshot}: no usable ivols")
        continue
    xi_stack = np.array(xi_stack)
    xi_mean = np.nanmean(xi_stack, axis=0)
    xi_std = np.nanstd(xi_stack, axis=0)

    z_val = res.attrs.get('z') if res is not None else None
    if z_val is None:
        z_val = get_snapshot_redshift(snapshot)
    z_label = f"{z_val:.2f}" if z_val is not None else "n/a"

    valid = np.isfinite(xi_mean) & (xi_mean > -1) & np.isfinite(r_ref)
    if not np.any(valid):
        print(f"Skipped {snapshot}: no finite xi after averaging")
        continue
    ax.loglog(r_ref[valid], xi_mean[valid], 'o-', label=f"{snapshot} (z={z_label}, n={n_used})")
    #ax.fill_between(r_ref[valid], xi_mean[valid] - xi_std[valid], xi_mean[valid] + xi_std[valid], alpha=0.15)

ax.set_xlabel('Separation r [Mpc/h]')
ax.set_ylabel(r'$\xi_{\mathrm{sat,cen}}(r)$')
ax.set_title('Satellite–Central Cross-Correlation (multiple redshifts)')
ax.legend(ncol=2, fontsize=9)
ax.grid(True, alpha=0.3, which='both')
plt.show()
