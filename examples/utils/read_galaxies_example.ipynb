# %% [markdown]
# # Read Galaxy Arrays Utility Example

# %%
import sys, os
if '/cosma/apps/durham/dc-hick2/galform_analysis' not in sys.path: sys.path.append('/cosma/apps/durham/dc-hick2/galform_analysis')
from src.utils.read_galaxies import read_galaxy_arrays
from src.config import get_base_dir

arrays, meta = read_galaxy_arrays(os.path.join(get_base_dir(), "iz155"), 0)
print(f"Fields: {list(arrays.keys())}")
